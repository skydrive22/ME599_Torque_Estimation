# %%
import numpy as np
import pandas as pd
import pysindy as ps

data = pd.read_csv('ReducedTorqueData.csv')
data.head()
# Out:
#     timeInS    i_aInA    i_bInA    i_cInA    u_aInV    u_bInV    u_cInV  \
# 0  0.000000  1.765625  3.453125  0.937500 -0.322917 -0.677083  1.000000
# 1  0.000001  1.578125  3.421875  0.859375 -0.177083 -0.750000  0.927083
# 2  0.000002  1.578125  3.562500  0.750000 -0.114583 -0.854167  0.968750
# 3  0.000003  1.765625  3.671875  0.640625 -0.104167 -0.822917  0.927083
# 4  0.000004  1.656250  3.671875  0.609375 -0.125000 -0.802083  0.927083
#
#    epsilon_elInRad
# 0        -2.403804
# 1        -2.403765
# 2        -2.403726
# 3        -2.403687
# 4        -2.403648

# %%
model = ps.SINDy(optimizer=None,
                feature_library=None, 
                differentiation_method=None, 
                feature_names=None)

# %%
t = data['timeInS']
X = data[data.columns[2:]]
# Out:
#      i_bInA    i_cInA    u_aInV    u_bInV    u_cInV  epsilon_elInRad
# 0  3.453125  0.937500 -0.322917 -0.677083  1.000000        -2.403804
# 1  3.421875  0.859375 -0.177083 -0.750000  0.927083        -2.403765
# 2  3.562500  0.750000 -0.114583 -0.854167  0.968750        -2.403726
# 3  3.671875  0.640625 -0.104167 -0.822917  0.927083        -2.403687
# 4  3.671875  0.609375 -0.125000 -0.802083  0.927083        -2.403648

# %%
model.fit(X, t=t)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model.fit(X, t=t)
#
# File ~/miniconda3/lib/python3.9/site-packages/pysindy/pysindy.py:325, in SINDy.fit(self, x, t, x_dot, u, multiple_trajectories, unbias, quiet, ensemble, library_ensemble, replace, n_candidates_to_drop, n_subset, n_models, ensemble_aggregator)
#     316 elif (
#     317     not isinstance(x, Sequence)
#     318     or (not isinstance(x_dot, Sequence) and x_dot is not None)
#     319     or (not isinstance(u, Sequence) and u is not None)
#     320 ):
#     321     raise TypeError(
#     322         "If multiple trajectories set, x and if included,"
#     323         "x_dot and u, must be Sequences"
#     324     )
# --> 325 x, x_dot, u = _comprehend_and_validate_inputs(
#     326     x, t, x_dot, u, self.feature_library
#     327 )
# ...
